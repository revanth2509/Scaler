# %%
import pandas as pd

# %%
df = pd.read_csv("netflix.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[df["type"] == "Movie"][df["listed_in"]!="Documentaries"]
# Out:
# C:\Users\revan\AppData\Local\Temp\ipykernel_12112\3875880889.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["type"] == "Movie"][df["listed_in"]!="Documentaries"]
#      show_id   type                             title  \
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# 13       s14  Movie  Confessions of an Invisible Girl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 6     Robert Cullen, José Luis Ucha
# ...

# %%
df[df["type"] == "Movie"]["listed_in"].str.contains("Movies")
# Out:
# 0       False
# 6        True
# 7        True
# 9       False
# 12       True
#         ...
# 8801     True
# 8802     True
# 8804     True
# 8805     True
# 8806     True
# Name: listed_in, Length: 6131, dtype: bool

# %%
df[df["type"] == "Movie"][df["listed_in"].str.contains("Movies")]
# Out:
# C:\Users\revan\AppData\Local\Temp\ipykernel_12112\3493451198.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["type"] == "Movie"][df["listed_in"].str.contains("Movies")]
#      show_id   type                                              title  \
# 6         s7  Movie                   My Little Pony: A New Generation
# 7         s8  Movie                                            Sankofa
# 12       s13  Movie                                       Je Suis Karl
# 13       s14  Movie                   Confessions of an Invisible Girl
# 16       s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# ...      ...    ...                                                ...
# 8801   s8802  Movie                                            Zinzana
# 8802   s8803  Movie                                             Zodiac
# 8804   s8805  Movie                                         Zombieland
# ...

# %%
df[df["type"] == "Movie"][df["listed_in"].str.contains("Documentaries")]
# Out:
# C:\Users\revan\AppData\Local\Temp\ipykernel_12112\2754331020.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["type"] == "Movie"][df["listed_in"].str.contains("Documentaries")]
#      show_id   type                                              title  \
# 0         s1  Movie                               Dick Johnson Is Dead
# 16       s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 45       s46  Movie                             My Heroes Were Cowboys
# 68       s69  Movie                                         Schumacher
# 88       s89  Movie           Blood Brothers: Malcolm X & Muhammad Ali
# ...      ...    ...                                                ...
# 8739   s8740  Movie                 Why We Fight: The Battle of Russia
# 8744   s8745  Movie                                           Williams
# 8746   s8747  Movie                                             Winnie
# ...

# %%
df["listed_in"].str.contains("Documentaries")
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: listed_in, Length: 8807, dtype: bool

# %%
df[df["listed_in"].str.contains("Documentaries")]
# Out:
#      show_id   type                                              title  \
# 0         s1  Movie                               Dick Johnson Is Dead
# 16       s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 45       s46  Movie                             My Heroes Were Cowboys
# 68       s69  Movie                                         Schumacher
# 88       s89  Movie           Blood Brothers: Malcolm X & Muhammad Ali
# ...      ...    ...                                                ...
# 8739   s8740  Movie                 Why We Fight: The Battle of Russia
# 8744   s8745  Movie                                           Williams
# 8746   s8747  Movie                                             Winnie
# 8756   s8757  Movie                                          Woodstock
# 8763   s8764  Movie                    WWII: Report from the Aleutians
#
#                                                director  \
# 0                                       Kirsten Johnson
# ...

# %%
#df.loc[df["listed_in"].str.contains("Documentaries"),"listed_in"] = "Documentaries"

# %%
df[df["listed_in"].str.contains("Movies")]["listed_in"].value_counts()
# Out:
# Comedy Movies           2002
# International Movies    1216
# Action Movies           1020
# Horror Movies            393
# Family Movies            319
# Romantic Movies          103
# Name: listed_in, dtype: int64

# %%
df.loc[df["listed_in"].str.contains("Thrillers"),"listed_in"] = "Other"

# %%
df.loc[df["listed_in"] == "Movies","listed_in"].value_counts()
# Out:
# Movies    57
# Name: listed_in, dtype: int64

# %%
df.loc[df["listed_in"] == "Independent Movies","listed_in"] = "Other"

# %%
df.loc[df["listed_in"].str.contains("Thrillers"),"listed_in"] = "Other"

# %%
df[df["listed_in"].str.contains("Dramas")].shape
# Out:
# (1002, 12)

# %%
#df.loc[df["listed_in"].str.contains("Action"),"listed_in"] = "Action Movies"

# %%
#df.loc[df["listed_in"].str.contains("Horror"),"listed_in"] = "Horror Movies"

# %%
#df.loc[df["listed_in"].str.contains("Comedies"),"listed_in"] = "Comedy Movies"

# %%
#df.loc[df["listed_in"].str.contains("International Movies"),"listed_in"] = "International Movies"

# %%
#df.loc[df["listed_in"].str.contains("Children & Family Movies"),"listed_in"] = "Family Movies"

# %%
#df.loc[df["listed_in"].str.contains("Romantic Movies"),"listed_in"] = "Romantic Movies"

# %%
#df.loc[df["listed_in"].str.contains("Music & Musicals"),"listed_in"] = "Music & Musicals"

# %%
#df.loc[df["listed_in"].str.contains("Sci-Fi & Fantasy"),"listed_in"] = "Sci-Fi & Fantasy"

# %%
df.loc[df["listed_in"].str.contains("Dramas"),"listed_in"] = "Dramas"

# %%
df["listed_in"].value_counts()
# Out:
# Comedy Movies                                                      2002
# International Movies                                               1216
# Action Movies                                                      1020
# Dramas                                                             1002
# Documentaries                                                       869
#                                                                    ...
# Anime Series, International TV Shows, Spanish-Language TV Shows       1
# International TV Shows, Romantic TV Shows, TV Mysteries               1
# Crime TV Shows, International TV Shows, TV Mysteries                  1
# British TV Shows, Classic & Cult TV, Kids' TV                         1
# Anime Features                                                        1
# Name: listed_in, Length: 91, dtype: int64

# %%
df[df["listed_in"].str.contains("Shows")]["listed_in"].value_counts()
# Out:
# Anime Series, International TV Shows                                 88
# International TV Shows, Korean TV Shows, Romantic TV Shows           65
# Crime TV Shows, International TV Shows, Spanish-Language TV Shows    62
# Crime TV Shows, Docuseries                                           50
# International TV Shows, Reality TV                                   38
#                                                                      ..
# Anime Series, International TV Shows, Spanish-Language TV Shows       1
# International TV Shows, Romantic TV Shows, TV Mysteries               1
# Crime TV Shows, International TV Shows, TV Mysteries                  1
# British TV Shows, Classic & Cult TV, Kids' TV                         1
# Classic & Cult TV, Kids' TV, Spanish-Language TV Shows                1
# Name: listed_in, Length: 67, dtype: int64

# %%
import pandas as pd, numpy as np
data = np.array([[1,2,3,'L1'],[4,5,6,'L2'],[7,8,9,'L3'],[4,8,np.nan,np.nan],[2,3,4,5],[7,9,np.nan,np.nan]],dtype='object')
df = pd.DataFrame(data,columns=['A','B','C','D'])

df
# Out:
#    A  B    C    D
# 0  1  2    3   L1
# 1  4  5    6   L2
# 2  7  8    9   L3
# 3  4  8  NaN  NaN
# 4  2  3    4    5
# 5  7  9  NaN  NaN

# %%
df.sort_values(by='A',inplace=True)
df.fillna(method='ffill')
# Out:
#    A  B  C   D
# 0  1  2  3  L1
# 4  2  3  4   5
# 1  4  5  6  L2
# 3  4  8  6  L2
# 2  7  8  9  L3
# 5  7  9  9  L3
